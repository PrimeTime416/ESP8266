# %%
usbPortX="/dev/tty*"
declare -a usbPortList

for file in $usbPortX
do
    if [ "$file" != "/dev/ttyUSB*" ] 
        then
            printf "$file\n"
#             usbPortList=(${usbPortList[*]} "$file\n")
#             printf "${usbPortList[@]}"
        else
            printf "NO USB PORTS FOUND!"
        
    fi
done
# Out:
# /dev/tty
# /dev/tty0
# /dev/tty1
# /dev/tty10
# /dev/tty11
# /dev/tty12
# /dev/tty13
# /dev/tty14
# /dev/tty15
# /dev/tty16
# /dev/tty17
# /dev/tty18
# /dev/tty19
# /dev/tty2
# /dev/tty20
# /dev/tty21
# /dev/tty22
# /dev/tty23
# /dev/tty24
# /dev/tty25
# /dev/tty26
# /dev/tty27
# /dev/tty28
# /dev/tty29
# /dev/tty3
# /dev/tty30
# /dev/tty31
# /dev/tty32
# /dev/tty33
# /dev/tty34
# /dev/tty35
# /dev/tty36
# /dev/tty37
# /dev/tty38
# /dev/tty39
# /dev/tty4
# /dev/tty40
# /dev/tty41
# /dev/tty42
# /dev/tty43
# /dev/tty44
# /dev/tty45
# /dev/tty46
# /dev/tty47
# /dev/tty48
# /dev/tty49
# /dev/tty5
# /dev/tty50
# /dev/tty51
# /dev/tty52
# /dev/tty53
# /dev/tty54
# /dev/tty55
# /dev/tty56
# /dev/tty57
# /dev/tty58
# /dev/tty59
# /dev/tty6
# /dev/tty60
# /dev/tty61
# /dev/tty62
# /dev/tty63
# /dev/tty7
# /dev/tty8
# /dev/tty9
# /dev/ttyprintk
# /dev/ttyS0
# /dev/ttyS1
# /dev/ttyS10
# /dev/ttyS11
# /dev/ttyS12
# /dev/ttyS13
# /dev/ttyS14
# /dev/ttyS15
# /dev/ttyS16
# /dev/ttyS17
# ...
